# %% [markdown]
# # Driftcast Quickstart
# This notebook demonstrates loading a YAML scenario, running a short simulation, and inspecting the resulting dataset.

# %%
from driftcast.config import load_config
from driftcast.sim.runner import run_simulation
cfg = load_config("configs/natl_subtropical_gyre.yaml")
ds = run_simulation(cfg)
ds
